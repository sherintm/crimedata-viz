# %%
# Import dependencies
# %config Completer.use_jedi = False

import pandas as pd
from sqlalchemy import create_engine
import datetime
import requests
import pymongo
from pprint import pprint
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Read the Criminal Incidents CSV file
crime_incidents_file = "Data/CriminalIncidentsData.csv"
crime_incidents_df = pd.read_csv(crime_incidents_file)
crime_incidents_df.head()
# Out:
#    Year Year ending       Police Region Local Government Area  \
# 0  2021       March  1 North West Metro               Banyule
# 1  2021       March  1 North West Metro              Brimbank
# 2  2021       March  1 North West Metro               Darebin
# 3  2021       March  1 North West Metro           Hobsons Bay
# 4  2021       March  1 North West Metro                  Hume
#
#   Incidents Recorded Rate per 100,000 population
# 0              6,308                     4,794.9
# 1             14,560                     7,132.9
# 2             11,513                     6,968.1
# 3              4,469                     4,583.9
# 4             15,540                     6,301.2

# %%
# Read the Offences Division CSV file
offence_file = "Data/OffenceDivisionData.csv"
offence_df = pd.read_csv(offence_file)
offence_df.head()
# Out:
#    Year Year ending Police Service Area Local Government Area  \
# 0  2021       March            Ballarat              Ballarat
# 1  2021       March            Ballarat              Ballarat
# 2  2021       March            Ballarat              Ballarat
# 3  2021       March            Ballarat              Ballarat
# 4  2021       March            Ballarat              Ballarat
#
#               Offence Division                Offence Subdivision  \
# 0  A Crimes against the person  A10 Homicide and related offences
# 1  A Crimes against the person   A20 Assault and related offences
# 2  A Crimes against the person   A20 Assault and related offences
# 3  A Crimes against the person   A20 Assault and related offences
# 4  A Crimes against the person   A20 Assault and related offences
#
#                                     Offence Subgroup Incidents Recorded  \
# 0                  A10 Homicide and related offences                  2
# 1                            A211 FV Serious assault                143
# 2                        A212 Non-FV Serious assault                131
# 3  A22 Assault police, emergency services or othe...                 34
# 4                             A231 FV Common assault                279
#
#   PSA Rate per 100,000 population LGA Rate per 100,000 population
# 0                             1.7                             1.8
# 1                           118.6                           126.5
# 2                           108.6                           115.9
# 3                            28.2                            30.1
# 4                           231.3                           246.8

# %%
# Read the Victims Data CSV file
victim_file = "Data/FamilyVictimsData.csv"
victim_df = pd.read_csv(victim_file)
victim_df.head()
# Out:
#    Year Year ending  AFM Sex AFM Age Group AFM Counter  \
# 0  2021       March  Females   00-04 years         242
# 1  2021       March  Females   05-09 years         543
# 2  2021       March  Females   10-14 years       1,696
# 3  2021       March  Females   15-17 years       2,262
# 4  2021       March  Females   18-19 years       2,165
#
#   Rate per 100,000 population
# 0                       127.8
# 1                       266.1
# 2                       870.1
# 3                     2,081.5
# 4                     2,994.0

# %%
crime_incidents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         870 non-null    int64
#  1   Year ending                  870 non-null    object
#  2   Police Region                870 non-null    object
#  3   Local Government Area        870 non-null    object
#  4   Incidents Recorded           870 non-null    object
#  5   Rate per 100,000 population  830 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 40.9+ KB

# %%
offence_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50287 entries, 0 to 50286
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             50287 non-null  int64
#  1   Year ending                      50287 non-null  object
#  2   Police Service Area              50287 non-null  object
#  3   Local Government Area            50287 non-null  object
#  4   Offence Division                 50287 non-null  object
#  5   Offence Subdivision              50287 non-null  object
#  6   Offence Subgroup                 50287 non-null  object
#  7   Incidents Recorded               50287 non-null  object
#  8   PSA Rate per 100,000 population  50287 non-null  object
#  9   LGA Rate per 100,000 population  50287 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.8+ MB

# %%
victim_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         270 non-null    int64
#  1   Year ending                  270 non-null    object
#  2   AFM Sex                      270 non-null    object
#  3   AFM Age Group                270 non-null    object
#  4   AFM Counter                  270 non-null    object
#  5   Rate per 100,000 population  270 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 12.8+ KB

# %%
crime_incidents_df_yrfilter = crime_incidents_df.loc[((crime_incidents_df['Year'] >= 2017) & (crime_incidents_df['Year'] <= 2021))]
crime_incidents_df_yrfilter
# Out:
#      Year Year ending                                    Police Region  \
# 0    2021       March                               1 North West Metro
# 1    2021       March                               1 North West Metro
# 2    2021       March                               1 North West Metro
# 3    2021       March                               1 North West Metro
# 4    2021       March                               1 North West Metro
# ..    ...         ...                                              ...
# 430  2017       March                                        4 Western
# 431  2017       March  Justice Institutions and Immigration Facilities
# 432  2017       March  Justice Institutions and Immigration Facilities
# 433  2017       March                               Unincorporated Vic
# 434  2017       March                               Unincorporated Vic
#
#                                 Local Government Area Incidents Recorded  \
# 0                                             Banyule              6,308
# 1                                            Brimbank             14,560
# 2                                             Darebin             11,513
# 3                                         Hobsons Bay              4,469
# 4                                                Hume             15,540
# ..                                                ...                ...
# 430                                             Total             66,704
# 431   Justice Institutions and Immigration Facilities              1,125
# 432                                             Total              1,125
# 433                                Unincorporated Vic                126
# 434                                             Total                126
#
#     Rate per 100,000 population
# 0                       4,794.9
# 1                       7,132.9
# 2                       6,968.1
# 3                       4,583.9
# 4                       6,301.2
# ..                          ...
# 430                     6,795.8
# 431                         NaN
# 432                         NaN
# 433                         NaN
# 434                         NaN
#
# [435 rows x 6 columns]

# %%
crime_incidents_df_clean = crime_incidents_df_yrfilter.loc[((crime_incidents_df_yrfilter['Local Government Area'] != 'Total') &
                                                           (crime_incidents_df_yrfilter['Local Government Area'] != ' Unincorporated Vic') &
                                                           (crime_incidents_df_yrfilter['Local Government Area'] != ' Justice Institutions and Immigration Facilities'))
                                                          ]
crime_incidents_df_clean['Local Government Area'] = crime_incidents_df_clean['Local Government Area'].str.strip()

# %%
crime_incidents_df_clean['Incidents Recorded'] = crime_incidents_df_clean['Incidents Recorded'].replace('[,]', '', regex=True).astype(int)

# %%
crime_incidents_df_clean['Rate per 100,000 population'] = crime_incidents_df_clean['Rate per 100,000 population'].replace('[,]', '', regex=True).astype(float)

# %%
crime_incidents_df_final = crime_incidents_df_clean[['Year', 'Local Government Area', 'Incidents Recorded', 'Rate per 100,000 population']]

# %%
crime_incidents_df_final = crime_incidents_df_final.rename(columns={'Year':'year',
                                                                   'Local Government Area':'lga',
                                                                   'Incidents Recorded': 'incidents_recorded',
                                                                   'Rate per 100,000 population': 'rate_per_100k_population'})

# %%
crime_incidents_df_sorted_final = crime_incidents_df_final.sort_values(by=['year', 'incidents_recorded'], ascending=False)

# %%
crime_incidents_df_sorted_final = crime_incidents_df_sorted_final.reset_index(drop=True)
crime_incidents_df_sorted_final
# Out:
#      year              lga  incidents_recorded  rate_per_100k_population
# 0    2021        Melbourne               26031                   15199.4
# 1    2021            Casey               16206                    4375.5
# 2    2021  Greater Geelong               15568                    5757.7
# 3    2021             Hume               15540                    6301.2
# 4    2021         Brimbank               14560                    7132.9
# ..    ...              ...                 ...                       ...
# 390  2017           Alpine                 280                    2215.5
# 391  2017           Towong                 174                    2881.3
# 392  2017           Buloke                 141                    2272.4
# 393  2017     Queenscliffe                 135                    4562.4
# 394  2017     West Wimmera                 123                    3158.7
#
# [395 rows x 4 columns]

# %%
offence_df_yrfilter = offence_df.loc[(offence_df['Year'] >= 2017) & (offence_df['Year'] <= 2021)]
offence_df_yrfilter.tail()
# Out:
#        Year Year ending Police Service Area Local Government Area  \
# 25258  2017       March        Yarra Ranges          Yarra Ranges
# 25259  2017       March        Yarra Ranges          Yarra Ranges
# 25260  2017       March        Yarra Ranges          Yarra Ranges
# 25261  2017       March        Yarra Ranges          Yarra Ranges
# 25262  2017       March        Yarra Ranges          Yarra Ranges
#
#        Offence Division                       Offence Subdivision  \
# 25258  F Other offences  F30 Other government regulatory offences
# 25259  F Other offences  F30 Other government regulatory offences
# 25260  F Other offences                F90 Miscellaneous offences
# 25261  F Other offences                F90 Miscellaneous offences
# 25262  F Other offences                F90 Miscellaneous offences
#
#                                 Offence Subgroup Incidents Recorded  \
# 25258  F33 Liquor and tobacco licensing offences                  3
# 25259                  F36 Prostitution offences                  1
# 25260                 F91 Environmental offences                  2
# 25261                     F93 Cruelty to animals                  2
# 25262           F94 Dangerous substance offences                  1
#
#       PSA Rate per 100,000 population LGA Rate per 100,000 population
# 25258                             1.9                             1.9
# 25259                             0.6                             0.6
# 25260                             1.3                             1.3
# 25261                             1.3                             1.3
# 25262                             0.6                             0.6

# %%
offence_df_yrfilter['Incidents Recorded'] = offence_df_yrfilter['Incidents Recorded'].replace('[\,]', '', regex=True).astype(int)
offence_df_yrfilter['LGA Rate per 100,000 population'] = offence_df_yrfilter['LGA Rate per 100,000 population'].replace('[\,]', '', regex=True).astype(float)

# %%
offence_df_clean = offence_df_yrfilter[['Year', 'Offence Division', 'Incidents Recorded', 'LGA Rate per 100,000 population']]
offence_df_clean.head()
# Out:
#    Year             Offence Division  Incidents Recorded  \
# 0  2021  A Crimes against the person                   2
# 1  2021  A Crimes against the person                 143
# 2  2021  A Crimes against the person                 131
# 3  2021  A Crimes against the person                  34
# 4  2021  A Crimes against the person                 279
#
#    LGA Rate per 100,000 population
# 0                              1.8
# 1                            126.5
# 2                            115.9
# 3                             30.1
# 4                            246.8

# %%
offence_list = offence_df_clean['Offence Division']
offence_new_list = []
for i in offence_list:
    offence_new_list.append(i[2:])
offence_new_list
# Out:
# ['Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Drug offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Public order and security offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Justice procedures offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Other offences',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Crimes against the person',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  'Property and deception offences',
#  ...]

# %%
offence_df_clean['new_offence_division_column'] = offence_new_list
offence_df_clean_new = offence_df_clean[['Year', 'new_offence_division_column', 'Incidents Recorded', 'LGA Rate per 100,000 population']]
offence_df_clean_new
# Out:
#        Year new_offence_division_column  Incidents Recorded  \
# 0      2021   Crimes against the person                   2
# 1      2021   Crimes against the person                 143
# 2      2021   Crimes against the person                 131
# 3      2021   Crimes against the person                  34
# 4      2021   Crimes against the person                 279
# ...     ...                         ...                 ...
# 25258  2017              Other offences                   3
# 25259  2017              Other offences                   1
# 25260  2017              Other offences                   2
# 25261  2017              Other offences                   2
# 25262  2017              Other offences                   1
#
#        LGA Rate per 100,000 population
# 0                                  1.8
# 1                                126.5
# 2                                115.9
# 3                                 30.1
# 4                                246.8
# ...                                ...
# 25258                              1.9
# 25259                              0.6
# 25260                              1.3
# 25261                              1.3
# 25262                              0.6
#
# [25263 rows x 4 columns]

# %%
grouped_offence_df = offence_df_clean.groupby(['Year', 'new_offence_division_column']).agg(
             Incidents=('Incidents Recorded','sum'),
             RatePer100k=('LGA Rate per 100,000 population', lambda x: x.sum() / x.count()))
grouped_offence_df['RatePer100k'] = grouped_offence_df['RatePer100k'].map("{:.2f}".format)
grouped_offence_df = grouped_offence_df.reset_index()
grouped_offence_df
# Out:
#     Year         new_offence_division_column  Incidents RatePer100k
# 0   2017           Crimes against the person      60636       56.61
# 1   2017                       Drug offences      15657       54.77
# 2   2017         Justice procedures offences      47663      101.62
# 3   2017                      Other offences        806        4.33
# 4   2017     Property and deception offences     265881      190.15
# 5   2017  Public order and security offences      24419       37.42
# 6   2018           Crimes against the person      60569       56.14
# 7   2018                       Drug offences      14538       48.63
# 8   2018         Justice procedures offences      45385       98.34
# 9   2018                      Other offences        696        4.30
# 10  2018     Property and deception offences     232161      169.51
# 11  2018  Public order and security offences      23758       36.10
# 12  2019           Crimes against the person      62799       56.65
# 13  2019                       Drug offences      16040       57.53
# 14  2019         Justice procedures offences      49135      102.72
# 15  2019                      Other offences        783        4.07
# 16  2019     Property and deception offences     231372      163.96
# 17  2019  Public order and security offences      23990       37.12
# 18  2020           Crimes against the person      64597       55.50
# 19  2020                       Drug offences      16394       52.97
# 20  2020         Justice procedures offences      51569      109.00
# 21  2020                      Other offences        696        4.22
# 22  2020     Property and deception offences     253376      177.41
# 23  2020  Public order and security offences      20302       30.19
# 24  2021           Crimes against the person      64242       56.35
# 25  2021                       Drug offences      18418       58.85
# 26  2021         Justice procedures offences      52973      115.54
# 27  2021                      Other offences      37934      115.23
# 28  2021     Property and deception offences     194058      142.42
# 29  2021  Public order and security offences      18666       29.23

# %%
grouped_offence_df_final = grouped_offence_df.rename(columns={'Year':'year', 'new_offence_division_column': 'offence_division',
                                                             'Incidents':'incidents', 'RatePer100k': 'rate_per_100k'})
grouped_offence_df_final = grouped_offence_df_final.sort_values(by=['year', 'incidents'], ascending=False)
grouped_offence_df_final = grouped_offence_df_final.reset_index(drop=True)
grouped_offence_df_final
# Out:
#     year                    offence_division  incidents rate_per_100k
# 0   2021     Property and deception offences     194058        142.42
# 1   2021           Crimes against the person      64242         56.35
# 2   2021         Justice procedures offences      52973        115.54
# 3   2021                      Other offences      37934        115.23
# 4   2021  Public order and security offences      18666         29.23
# 5   2021                       Drug offences      18418         58.85
# 6   2020     Property and deception offences     253376        177.41
# 7   2020           Crimes against the person      64597         55.50
# 8   2020         Justice procedures offences      51569        109.00
# 9   2020  Public order and security offences      20302         30.19
# 10  2020                       Drug offences      16394         52.97
# 11  2020                      Other offences        696          4.22
# 12  2019     Property and deception offences     231372        163.96
# 13  2019           Crimes against the person      62799         56.65
# 14  2019         Justice procedures offences      49135        102.72
# 15  2019  Public order and security offences      23990         37.12
# 16  2019                       Drug offences      16040         57.53
# 17  2019                      Other offences        783          4.07
# 18  2018     Property and deception offences     232161        169.51
# 19  2018           Crimes against the person      60569         56.14
# 20  2018         Justice procedures offences      45385         98.34
# 21  2018  Public order and security offences      23758         36.10
# 22  2018                       Drug offences      14538         48.63
# 23  2018                      Other offences        696          4.30
# 24  2017     Property and deception offences     265881        190.15
# 25  2017           Crimes against the person      60636         56.61
# 26  2017         Justice procedures offences      47663        101.62
# 27  2017  Public order and security offences      24419         37.42
# 28  2017                       Drug offences      15657         54.77
# 29  2017                      Other offences        806          4.33

# %%
victim_df_clean_gender = victim_df.loc[victim_df['AFM Sex'] != 'People']
victim_df_clean = victim_df_clean_gender.loc[victim_df_clean_gender['AFM Age Group'] != 'Total']
victim_df_clean['AFM Counter'] = victim_df_clean['AFM Counter'].replace('[,]', '', regex=True).astype(int)
victim_df_clean_final = victim_df_clean[['Year', 'AFM Sex', 'AFM Age Group', 'AFM Counter']]
victim_df_clean_final.head()
# Out:
#    Year  AFM Sex AFM Age Group  AFM Counter
# 0  2021  Females   00-04 years          242
# 1  2021  Females   05-09 years          543
# 2  2021  Females   10-14 years         1696
# 3  2021  Females   15-17 years         2262
# 4  2021  Females   18-19 years         2165

# %%
grouped_victim_df = victim_df_clean_final.groupby(['Year','AFM Age Group','AFM Sex']).sum()
grouped_victim_df = grouped_victim_df.reset_index()
grouped_victim_df_final = grouped_victim_df.rename(columns={'Year': 'year',
                                                           'AFM Age Group': 'afm_age_group',
                                                           'AFM Sex': 'afm_gender',
                                                           'AFM Counter': 'afm_counter'})
grouped_victim_df_final.head()
# Out:
#    year afm_age_group afm_gender  afm_counter
# 0  2017   00-04 years    Females          319
# 1  2017   00-04 years      Males          362
# 2  2017   05-09 years    Females          683
# 3  2017   05-09 years      Males          877
# 4  2017   10-14 years    Females         1689

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
client.drop_database('crime_database')
# Define the 'classDB' database in Mongo
db = client.crime_database

# %%
collection_crime = db['crime_table']
collection_victim = db['victim_table']
collection_offence = db['offence_table']
collection_lga_data = db['lga_data_table']

# %%
crime_incidents_dict = crime_incidents_df_sorted_final.to_dict("records")

# %%
collection_crime.insert_many(crime_incidents_dict)

# %%
grouped_victim_dict = grouped_victim_df_final.to_dict("records")

# %%
collection_victim.insert_many(grouped_victim_dict)

# %%
grouped_offence_dict = grouped_offence_df_final.to_dict("records")

# %%
collection_offence.insert_many(grouped_offence_dict)

# %%
geojson_url = "https://data.gov.au/geoserver/vic-local-government-areas-psma-administrative-boundaries/wfs?request=GetFeature&typeName=ckan_bdf92691_c6fe_42b9_a0e2_a4cd716fa811&outputFormat=json"
response = requests.get(geojson_url)
response_data = response.json()

# %%
collection_lga_data.insert_many(response_data['features'])

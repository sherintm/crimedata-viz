# %%
# %config Completer.use_jedi = False

import pandas as pd
from sqlalchemy import create_engine
# from config import *
import datetime
pd.options.mode.chained_assignment = None  # default='warn'
import pymongo

# %%
crime_incidents_file = "Data/CriminalIncidentsData.csv"
crime_incidents_df = pd.read_csv(crime_incidents_file)
crime_incidents_df.head()
# Out:
#    Year Year ending       Police Region Local Government Area  \
# 0  2021       March  1 North West Metro               Banyule
# 1  2021       March  1 North West Metro              Brimbank
# 2  2021       March  1 North West Metro               Darebin
# 3  2021       March  1 North West Metro           Hobsons Bay
# 4  2021       March  1 North West Metro                  Hume
#
#   Incidents Recorded Rate per 100,000 population
# 0              6,308                     4,794.9
# 1             14,560                     7,132.9
# 2             11,513                     6,968.1
# 3              4,469                     4,583.9
# 4             15,540                     6,301.2

# %%
offence_file = "Data/OffenceDivisionData.csv"
offence_df = pd.read_csv(offence_file)
offence_df.head()
# Out:
#    Year Year ending Police Service Area Local Government Area  \
# 0  2021       March            Ballarat              Ballarat
# 1  2021       March            Ballarat              Ballarat
# 2  2021       March            Ballarat              Ballarat
# 3  2021       March            Ballarat              Ballarat
# 4  2021       March            Ballarat              Ballarat
#
#               Offence Division                Offence Subdivision  \
# 0  A Crimes against the person  A10 Homicide and related offences
# 1  A Crimes against the person   A20 Assault and related offences
# 2  A Crimes against the person   A20 Assault and related offences
# 3  A Crimes against the person   A20 Assault and related offences
# 4  A Crimes against the person   A20 Assault and related offences
#
#                                     Offence Subgroup Incidents Recorded  \
# 0                  A10 Homicide and related offences                  2
# 1                            A211 FV Serious assault                143
# 2                        A212 Non-FV Serious assault                131
# 3  A22 Assault police, emergency services or othe...                 34
# 4                             A231 FV Common assault                279
#
#   PSA Rate per 100,000 population LGA Rate per 100,000 population
# 0                             1.7                             1.8
# 1                           118.6                           126.5
# 2                           108.6                           115.9
# 3                            28.2                            30.1
# 4                           231.3                           246.8

# %%
victim_file = "Data/FamilyVictimsData.csv"
victim_df = pd.read_csv(victim_file)
victim_df.head()
# Out:
#    Year Year ending  AFM Sex AFM Age Group AFM Counter  \
# 0  2021       March  Females   00-04 years         242
# 1  2021       March  Females   05-09 years         543
# 2  2021       March  Females   10-14 years       1,696
# 3  2021       March  Females   15-17 years       2,262
# 4  2021       March  Females   18-19 years       2,165
#
#   Rate per 100,000 population
# 0                       127.8
# 1                       266.1
# 2                       870.1
# 3                     2,081.5
# 4                     2,994.0

# %%
crime_incidents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         870 non-null    int64
#  1   Year ending                  870 non-null    object
#  2   Police Region                870 non-null    object
#  3   Local Government Area        870 non-null    object
#  4   Incidents Recorded           870 non-null    object
#  5   Rate per 100,000 population  830 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 40.9+ KB

# %%
offence_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50287 entries, 0 to 50286
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             50287 non-null  int64
#  1   Year ending                      50287 non-null  object
#  2   Police Service Area              50287 non-null  object
#  3   Local Government Area            50287 non-null  object
#  4   Offence Division                 50287 non-null  object
#  5   Offence Subdivision              50287 non-null  object
#  6   Offence Subgroup                 50287 non-null  object
#  7   Incidents Recorded               50287 non-null  object
#  8   PSA Rate per 100,000 population  50287 non-null  object
#  9   LGA Rate per 100,000 population  50287 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.8+ MB

# %%
victim_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         270 non-null    int64
#  1   Year ending                  270 non-null    object
#  2   AFM Sex                      270 non-null    object
#  3   AFM Age Group                270 non-null    object
#  4   AFM Counter                  270 non-null    object
#  5   Rate per 100,000 population  270 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 12.8+ KB

# %%
crime_incidents_df_yrfilter = crime_incidents_df.loc[((crime_incidents_df['Year'] >= 2017) & (crime_incidents_df['Year'] <= 2021))]
crime_incidents_df_yrfilter
# Out:
#      Year Year ending                                    Police Region  \
# 0    2021       March                               1 North West Metro
# 1    2021       March                               1 North West Metro
# 2    2021       March                               1 North West Metro
# 3    2021       March                               1 North West Metro
# 4    2021       March                               1 North West Metro
# ..    ...         ...                                              ...
# 430  2017       March                                        4 Western
# 431  2017       March  Justice Institutions and Immigration Facilities
# 432  2017       March  Justice Institutions and Immigration Facilities
# 433  2017       March                               Unincorporated Vic
# 434  2017       March                               Unincorporated Vic
#
#                                 Local Government Area Incidents Recorded  \
# 0                                             Banyule              6,308
# 1                                            Brimbank             14,560
# 2                                             Darebin             11,513
# 3                                         Hobsons Bay              4,469
# 4                                                Hume             15,540
# ..                                                ...                ...
# 430                                             Total             66,704
# 431   Justice Institutions and Immigration Facilities              1,125
# 432                                             Total              1,125
# 433                                Unincorporated Vic                126
# 434                                             Total                126
#
#     Rate per 100,000 population
# 0                       4,794.9
# 1                       7,132.9
# 2                       6,968.1
# 3                       4,583.9
# 4                       6,301.2
# ..                          ...
# 430                     6,795.8
# 431                         NaN
# 432                         NaN
# 433                         NaN
# 434                         NaN
#
# [435 rows x 6 columns]

# %%
crime_incidents_df_clean = crime_incidents_df_yrfilter.loc[((crime_incidents_df_yrfilter['Local Government Area'] != 'Total') &
                                                           (crime_incidents_df_yrfilter['Local Government Area'] != ' Unincorporated Vic') &
                                                           (crime_incidents_df_yrfilter['Local Government Area'] != ' Justice Institutions and Immigration Facilities'))
                                                          ]
crime_incidents_df_clean['Local Government Area'] = crime_incidents_df_clean['Local Government Area'].str.strip()

# %%
crime_incidents_df_clean['Incidents Recorded'] = crime_incidents_df_clean['Incidents Recorded'].replace('[,]', '', regex=True).astype(int)

# %%
crime_incidents_df_clean['Rate per 100,000 population'] = crime_incidents_df_clean['Rate per 100,000 population'].replace('[,]', '', regex=True).astype(float)

# %%
crime_incidents_df_final = crime_incidents_df_clean[['Year', 'Local Government Area', 'Incidents Recorded', 'Rate per 100,000 population']]

# %%
crime_incidents_df_final = crime_incidents_df_final.rename(columns={'Year':'year',
                                                                   'Local Government Area':'lga',
                                                                   'Incidents Recorded': 'incidents_recorded',
                                                                   'Rate per 100,000 population': 'rate_per_100k_population'})

# %%
crime_incidents_df_sorted_final = crime_incidents_df_final.sort_values(by=['year', 'incidents_recorded'], ascending=False)

# %%
crime_incidents_df_sorted_final = crime_incidents_df_sorted_final.reset_index(drop=True)
crime_incidents_df_sorted_final
# Out:
#      year              lga  incidents_recorded  rate_per_100k_population
# 0    2021        Melbourne               26031                   15199.4
# 1    2021            Casey               16206                    4375.5
# 2    2021  Greater Geelong               15568                    5757.7
# 3    2021             Hume               15540                    6301.2
# 4    2021         Brimbank               14560                    7132.9
# ..    ...              ...                 ...                       ...
# 390  2017           Alpine                 280                    2215.5
# 391  2017           Towong                 174                    2881.3
# 392  2017           Buloke                 141                    2272.4
# 393  2017     Queenscliffe                 135                    4562.4
# 394  2017     West Wimmera                 123                    3158.7
#
# [395 rows x 4 columns]

# %%
offence_df_yrfilter = offence_df.loc[(offence_df['Year'] >= 2017) & (offence_df['Year'] <= 2021)]
offence_df_yrfilter.tail()
# Out:
#        Year Year ending Police Service Area Local Government Area  \
# 25258  2017       March        Yarra Ranges          Yarra Ranges
# 25259  2017       March        Yarra Ranges          Yarra Ranges
# 25260  2017       March        Yarra Ranges          Yarra Ranges
# 25261  2017       March        Yarra Ranges          Yarra Ranges
# 25262  2017       March        Yarra Ranges          Yarra Ranges
#
#        Offence Division                       Offence Subdivision  \
# 25258  F Other offences  F30 Other government regulatory offences
# 25259  F Other offences  F30 Other government regulatory offences
# 25260  F Other offences                F90 Miscellaneous offences
# 25261  F Other offences                F90 Miscellaneous offences
# 25262  F Other offences                F90 Miscellaneous offences
#
#                                 Offence Subgroup Incidents Recorded  \
# 25258  F33 Liquor and tobacco licensing offences                  3
# 25259                  F36 Prostitution offences                  1
# 25260                 F91 Environmental offences                  2
# 25261                     F93 Cruelty to animals                  2
# 25262           F94 Dangerous substance offences                  1
#
#       PSA Rate per 100,000 population LGA Rate per 100,000 population
# 25258                             1.9                             1.9
# 25259                             0.6                             0.6
# 25260                             1.3                             1.3
# 25261                             1.3                             1.3
# 25262                             0.6                             0.6

# %%
offence_df_yrfilter['Incidents Recorded'] = offence_df_yrfilter['Incidents Recorded'].replace('[\,]', '', regex=True).astype(int)
offence_df_yrfilter['LGA Rate per 100,000 population'] = offence_df_yrfilter['LGA Rate per 100,000 population'].replace('[\,]', '', regex=True).astype(float)

# %%
offence_df_clean = offence_df_yrfilter[['Year', 'Offence Division', 'Incidents Recorded', 'LGA Rate per 100,000 population']]
offence_df_clean.head()
# Out:
#    Year             Offence Division  Incidents Recorded  \
# 0  2021  A Crimes against the person                   2
# 1  2021  A Crimes against the person                 143
# 2  2021  A Crimes against the person                 131
# 3  2021  A Crimes against the person                  34
# 4  2021  A Crimes against the person                 279
#
#    LGA Rate per 100,000 population
# 0                              1.8
# 1                            126.5
# 2                            115.9
# 3                             30.1
# 4                            246.8

# %%
grouped_offence_df = offence_df_clean.groupby(['Year', 'Offence Division']).agg(
             Incidents=('Incidents Recorded','sum'),
             RatePer100k=('LGA Rate per 100,000 population', lambda x: x.sum() / x.count()))
grouped_offence_df['RatePer100k'] = grouped_offence_df['RatePer100k'].map("{:.2f}".format)
grouped_offence_df = grouped_offence_df.reset_index()
grouped_offence_df
# Out:
#     Year                      Offence Division  Incidents RatePer100k
# 0   2017           A Crimes against the person      60636       56.61
# 1   2017     B Property and deception offences     265881      190.15
# 2   2017                       C Drug offences      15657       54.77
# 3   2017  D Public order and security offences      24419       37.42
# 4   2017         E Justice procedures offences      47663      101.62
# 5   2017                      F Other offences        806        4.33
# 6   2018           A Crimes against the person      60569       56.14
# 7   2018     B Property and deception offences     232161      169.51
# 8   2018                       C Drug offences      14538       48.63
# 9   2018  D Public order and security offences      23758       36.10
# 10  2018         E Justice procedures offences      45385       98.34
# 11  2018                      F Other offences        696        4.30
# 12  2019           A Crimes against the person      62799       56.65
# 13  2019     B Property and deception offences     231372      163.96
# 14  2019                       C Drug offences      16040       57.53
# 15  2019  D Public order and security offences      23990       37.12
# 16  2019         E Justice procedures offences      49135      102.72
# 17  2019                      F Other offences        783        4.07
# 18  2020           A Crimes against the person      64597       55.50
# 19  2020     B Property and deception offences     253376      177.41
# 20  2020                       C Drug offences      16394       52.97
# 21  2020  D Public order and security offences      20302       30.19
# 22  2020         E Justice procedures offences      51569      109.00
# 23  2020                      F Other offences        696        4.22
# 24  2021           A Crimes against the person      64242       56.35
# 25  2021     B Property and deception offences     194058      142.42
# 26  2021                       C Drug offences      18418       58.85
# 27  2021  D Public order and security offences      18666       29.23
# 28  2021         E Justice procedures offences      52973      115.54
# 29  2021                      F Other offences      37934      115.23

# %%
grouped_offence_df_final = grouped_offence_df.rename(columns={'Year':'year', 'Offence Division': 'offence_division',
                                                             'Incidents':'incidents', 'RatePer100k': 'rate_per_100k'})
grouped_offence_df_final
# Out:
#     year                      offence_division  incidents rate_per_100k
# 0   2017           A Crimes against the person      60636         56.61
# 1   2017     B Property and deception offences     265881        190.15
# 2   2017                       C Drug offences      15657         54.77
# 3   2017  D Public order and security offences      24419         37.42
# 4   2017         E Justice procedures offences      47663        101.62
# 5   2017                      F Other offences        806          4.33
# 6   2018           A Crimes against the person      60569         56.14
# 7   2018     B Property and deception offences     232161        169.51
# 8   2018                       C Drug offences      14538         48.63
# 9   2018  D Public order and security offences      23758         36.10
# 10  2018         E Justice procedures offences      45385         98.34
# 11  2018                      F Other offences        696          4.30
# 12  2019           A Crimes against the person      62799         56.65
# 13  2019     B Property and deception offences     231372        163.96
# 14  2019                       C Drug offences      16040         57.53
# 15  2019  D Public order and security offences      23990         37.12
# 16  2019         E Justice procedures offences      49135        102.72
# 17  2019                      F Other offences        783          4.07
# 18  2020           A Crimes against the person      64597         55.50
# 19  2020     B Property and deception offences     253376        177.41
# 20  2020                       C Drug offences      16394         52.97
# 21  2020  D Public order and security offences      20302         30.19
# 22  2020         E Justice procedures offences      51569        109.00
# 23  2020                      F Other offences        696          4.22
# 24  2021           A Crimes against the person      64242         56.35
# 25  2021     B Property and deception offences     194058        142.42
# 26  2021                       C Drug offences      18418         58.85
# 27  2021  D Public order and security offences      18666         29.23
# 28  2021         E Justice procedures offences      52973        115.54
# 29  2021                      F Other offences      37934        115.23

# %%
victim_df_clean_gender = victim_df.loc[victim_df['AFM Sex'] != 'People']
victim_df_clean = victim_df_clean_gender.loc[victim_df_clean_gender['AFM Age Group'] != 'Total']
victim_df_clean['AFM Counter'] = victim_df_clean['AFM Counter'].replace('[,]', '', regex=True).astype(int)
victim_df_clean_final = victim_df_clean[['Year', 'AFM Sex', 'AFM Age Group', 'AFM Counter']]
victim_df_clean_final
# Out:
#      Year  AFM Sex      AFM Age Group  AFM Counter
# 0    2021  Females        00-04 years          242
# 1    2021  Females        05-09 years          543
# 2    2021  Females        10-14 years         1696
# 3    2021  Females        15-17 years         2262
# 4    2021  Females        18-19 years         2165
# ..    ...      ...                ...          ...
# 246  2017    Males        55-59 years         1053
# 247  2017    Males        60-64 years          707
# 248  2017    Males        65-69 years          593
# 249  2017    Males        70-74 years          389
# 250  2017    Males  75 years and over          381
#
# [170 rows x 4 columns]

# %%
grouped_victim_df = victim_df_clean_final.groupby(['Year','AFM Age Group','AFM Sex']).sum()
grouped_victim_df = grouped_victim_df.reset_index()
grouped_victim_df_final = grouped_victim_df.rename(columns={'Year': 'year',
                                                           'AFM Age Group': 'afm_age_group',
                                                           'AFM Sex': 'afm_gender',
                                                           'AFM Counter': 'afm_counter'})
grouped_victim_df_final
# Out:
#      year      afm_age_group afm_gender  afm_counter
# 0    2017        00-04 years    Females          319
# 1    2017        00-04 years      Males          362
# 2    2017        05-09 years    Females          683
# 3    2017        05-09 years      Males          877
# 4    2017        10-14 years    Females         1689
# ..    ...                ...        ...          ...
# 165  2021        65-69 years      Males          784
# 166  2021        70-74 years    Females          889
# 167  2021        70-74 years      Males          532
# 168  2021  75 years and over    Females         1103
# 169  2021  75 years and over      Males          615
#
# [170 rows x 4 columns]

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.crimedataDB

# %%
collection_crime = db['crimeDB']
collection_victim = db['victimDB']
collection_offence = db['offenceDB']

# %%
crime_incidents_dict = crime_incidents_df_sorted_final.to_dict("records")

# %%
crime_incidents_dict
# Out:
# [{'year': 2021,
#   'lga': 'Melbourne',
#   'incidents_recorded': 26031,
#   'rate_per_100k_population': 15199.4},
#  {'year': 2021,
#   'lga': 'Casey',
#   'incidents_recorded': 16206,
#   'rate_per_100k_population': 4375.5},
#  {'year': 2021,
#   'lga': 'Greater Geelong',
#   'incidents_recorded': 15568,
#   'rate_per_100k_population': 5757.7},
#  {'year': 2021,
#   'lga': 'Hume',
#   'incidents_recorded': 15540,
#   'rate_per_100k_population': 6301.2},
#  {'year': 2021,
#   'lga': 'Brimbank',
#   'incidents_recorded': 14560,
#   'rate_per_100k_population': 7132.9},
#  {'year': 2021,
#   'lga': 'Greater Dandenong',
#   'incidents_recorded': 14257,
#   'rate_per_100k_population': 8631.1},
#  {'year': 2021,
#   'lga': 'Wyndham',
#   'incidents_recorded': 12748,
#   'rate_per_100k_population': 4369.6},
#  {'year': 2021,
#   'lga': 'Darebin',
#   'incidents_recorded': 11513,
#   'rate_per_100k_population': 6968.1},
#  {'year': 2021,
#   'lga': 'Whittlesea',
#   'incidents_recorded': 11475,
#   'rate_per_100k_population': 4804.3},
#  {'year': 2021,
#   'lga': 'Yarra',
#   'incidents_recorded': 10861,
#   'rate_per_100k_population': 10719.2},
#  {'year': 2021,
#   'lga': 'Port Phillip',
#   'incidents_recorded': 10235,
#   'rate_per_100k_population': 8974.7},
#  {'year': 2021,
#   'lga': 'Frankston',
#   'incidents_recorded': 10234,
#   'rate_per_100k_population': 7147.1},
#  {'year': 2021,
#   'lga': 'Moreland',
#   'incidents_recorded': 10182,
#   'rate_per_100k_population': 5432.9},
#  {'year': 2021,
#   'lga': 'Melton',
#   'incidents_recorded': 9902,
#   'rate_per_100k_population': 5486.3},
#  {'year': 2021,
#   'lga': 'Monash',
#   'incidents_recorded': 9593,
#   'rate_per_100k_population': 4806.6},
#  {'year': 2021,
#   'lga': 'Latrobe',
#   'incidents_recorded': 9109,
#   'rate_per_100k_population': 11944.3},
#  {'year': 2021,
#   'lga': 'Stonnington',
#   'incidents_recorded': 8981,
#   'rate_per_100k_population': 7736.5},
#  {'year': 2021,
#   'lga': 'Knox',
#   'incidents_recorded': 8305,
#   'rate_per_100k_population': 5048.0},
#  {'year': 2021,
#   'lga': 'Kingston',
#   'incidents_recorded': 8066,
#   'rate_per_100k_population': 4854.2},
#  {'year': 2021,
#   'lga': 'Greater Bendigo',
#   'incidents_recorded': 8029,
#   'rate_per_100k_population': 6595.4},
#  {'year': 2021,
#   'lga': 'Mornington Peninsula',
#   'incidents_recorded': 7648,
#   'rate_per_100k_population': 4511.8},
#  {'year': 2021,
#   'lga': 'Ballarat',
#   'incidents_recorded': 7222,
#   'rate_per_100k_population': 6388.1},
#  {'year': 2021,
#   'lga': 'Maribyrnong',
#   'incidents_recorded': 7060,
#   'rate_per_100k_population': 7502.6},
#  {'year': 2021,
#   'lga': 'Whitehorse',
#   'incidents_recorded': 6968,
#   'rate_per_100k_population': 3917.7},
#  {'year': 2021,
#   'lga': 'Banyule',
#   'incidents_recorded': 6308,
#   'rate_per_100k_population': 4794.9},
#  {'year': 2021,
#   'lga': 'Yarra Ranges',
#   'incidents_recorded': 6154,
#   'rate_per_100k_population': 3863.4},
#  {'year': 2021,
#   'lga': 'Moonee Valley',
#   'incidents_recorded': 6121,
#   'rate_per_100k_population': 4673.2},
#  {'year': 2021,
#   'lga': 'Glen Eira',
#   'incidents_recorded': 6036,
#   'rate_per_100k_population': 3858.4},
#  {'year': 2021,
#   'lga': 'Boroondara',
#   'incidents_recorded': 5965,
#   'rate_per_100k_population': 3333.4},
#  {'year': 2021,
#   'lga': 'Greater Shepparton',
#   'incidents_recorded': 5950,
#   'rate_per_100k_population': 8855.8},
#  {'year': 2021,
#   'lga': 'Maroondah',
#   'incidents_recorded': 5726,
#   'rate_per_100k_population': 4812.4},
#  {'year': 2021,
#   'lga': 'Cardinia',
#   'incidents_recorded': 5572,
#   'rate_per_100k_population': 4697.9},
#  {'year': 2021,
#   'lga': 'Hobsons Bay',
#   'incidents_recorded': 4469,
#   'rate_per_100k_population': 4583.9},
#  {'year': 2021,
#   'lga': 'Mildura',
#   'incidents_recorded': 4417,
#   'rate_per_100k_population': 7929.3},
#  {'year': 2021,
#   'lga': 'Bayside',
#   'incidents_recorded': 3839,
#   'rate_per_100k_population': 3584.8},
#  {'year': 2021,
#   'lga': 'East Gippsland',
#   'incidents_recorded': 3639,
#   'rate_per_100k_population': 7569.9},
#  {'year': 2021,
#   'lga': 'Baw Baw',
#   'incidents_recorded': 3599,
#   'rate_per_100k_population': 6449.0},
#  {'year': 2021,
#   'lga': 'Manningham',
#   'incidents_recorded': 3380,
#   'rate_per_100k_population': 2647.1},
#  {'year': 2021,
#   'lga': 'Wellington',
#   'incidents_recorded': 3237,
#   'rate_per_100k_population': 7172.6},
#  {'year': 2021,
#   'lga': 'Mitchell',
#   'incidents_recorded': 3183,
#   'rate_per_100k_population': 6552.2},
#  {'year': 2021,
#   'lga': 'Campaspe',
#   'incidents_recorded': 2459,
#   'rate_per_100k_population': 6539.2},
#  {'year': 2021,
#   'lga': 'Wodonga',
#   'incidents_recorded': 2426,
#   'rate_per_100k_population': 5642.9},
#  {'year': 2021,
#   'lga': 'Warrnambool',
#   'incidents_recorded': 2209,
#   'rate_per_100k_population': 6229.8},
#  {'year': 2021,
#   'lga': 'Bass Coast',
#   'incidents_recorded': 2102,
#   'rate_per_100k_population': 5454.5},
#  {'year': 2021,
#   'lga': 'Moorabool',
#   'incidents_recorded': 1994,
#   'rate_per_100k_population': 5416.1},
#  {'year': 2021,
#   'lga': 'Swan Hill',
#   'incidents_recorded': 1861,
#   'rate_per_100k_population': 9133.6},
#  {'year': 2021,
#   'lga': 'Macedon Ranges',
#   'incidents_recorded': 1860,
#   'rate_per_100k_population': 3604.1},
#  {'year': 2021,
#   'lga': 'Wangaratta',
#   'incidents_recorded': 1665,
#   'rate_per_100k_population': 5707.5},
#  {'year': 2021,
#   'lga': 'Moira',
#   'incidents_recorded': 1635,
#   'rate_per_100k_population': 5458.6},
#  {'year': 2021,
#   'lga': 'Nillumbik',
#   'incidents_recorded': 1525,
#   'rate_per_100k_population': 2349.4},
#  {'year': 2021,
#   'lga': 'Horsham',
#   'incidents_recorded': 1475,
#   'rate_per_100k_population': 7391.8},
#  {'year': 2021,
#   'lga': 'South Gippsland',
#   'incidents_recorded': 1267,
#   'rate_per_100k_population': 4157.9},
#  {'year': 2021,
#   'lga': 'Colac-Otway',
#   'incidents_recorded': 1228,
#   'rate_per_100k_population': 5678.4},
#  {'year': 2021,
#   'lga': 'Surf Coast',
#   'incidents_recorded': 1165,
#   'rate_per_100k_population': 3254.7},
#  {'year': 2021,
#   'lga': 'Ararat',
#   'incidents_recorded': 1092,
#   'rate_per_100k_population': 9104.3},
#  {'year': 2021,
#   'lga': 'Glenelg',
#   'incidents_recorded': 1052,
#   'rate_per_100k_population': 5380.3},
#  {'year': 2021,
#   'lga': 'Benalla',
#   'incidents_recorded': 1003,
#   'rate_per_100k_population': 7053.5},
#  {'year': 2021,
#   'lga': 'Northern Grampians',
#   'incidents_recorded': 899,
#   'rate_per_100k_population': 7974.1},
#  {'year': 2021,
#   'lga': 'Central Goldfields',
#   'incidents_recorded': 823,
#   'rate_per_100k_population': 6304.6},
#  {'year': 2021,
#   'lga': 'Southern Grampians',
#   'incidents_recorded': 796,
#   'rate_per_100k_population': 4962.0},
#  {'year': 2021,
#   'lga': 'Mount Alexander',
#   'incidents_recorded': 730,
#   'rate_per_100k_population': 3623.6},
#  {'year': 2021,
#   'lga': 'Corangamite',
#   'incidents_recorded': 687,
#   'rate_per_100k_population': 4371.6},
#  {'year': 2021,
#   'lga': 'Murrindindi',
#   'incidents_recorded': 666,
#   'rate_per_100k_population': 4463.1},
#  {'year': 2021,
#   'lga': 'Gannawarra',
#   'incidents_recorded': 642,
#   'rate_per_100k_population': 6217.5},
#  {'year': 2021,
#   'lga': 'Moyne',
#   'incidents_recorded': 513,
#   'rate_per_100k_population': 3021.0},
#  {'year': 2021,
#   'lga': 'Hepburn',
#   'incidents_recorded': 509,
#   'rate_per_100k_population': 3144.7},
#  {'year': 2021,
#   'lga': 'Strathbogie',
#   'incidents_recorded': 457,
#   'rate_per_100k_population': 4128.4},
#  {'year': 2021,
#   'lga': 'Golden Plains',
#   'incidents_recorded': 454,
#   'rate_per_100k_population': 1837.4},
#  {'year': 2021,
#   'lga': 'Indigo',
#   'incidents_recorded': 431,
#   'rate_per_100k_population': 2517.8},
#  {'year': 2021,
#   'lga': 'Loddon',
#   'incidents_recorded': 413,
#   'rate_per_100k_population': 5525.9},
#  {'year': 2021,
#   'lga': 'Alpine',
#   'incidents_recorded': 400,
#   'rate_per_100k_population': 3053.8},
#  {'year': 2021,
#   'lga': 'Mansfield',
#   'incidents_recorded': 390,
#   'rate_per_100k_population': 4068.1},
#  {'year': 2021,
#   'lga': 'Pyrenees',
#   'incidents_recorded': 345,
#   'rate_per_100k_population': 4562.2},
#  {'year': 2021,
#   'lga': 'Yarriambiack',
#   'incidents_recorded': 335,
#   'rate_per_100k_population': 5197.1},
#  {'year': 2021,
#   'lga': 'Hindmarsh',
#   'incidents_recorded': 289,
#   'rate_per_100k_population': 5238.0},
#  {'year': 2021,
#   'lga': 'Buloke',
#   'incidents_recorded': 243,
#   'rate_per_100k_population': 4030.5},
#  {'year': 2021,
#   'lga': 'Towong',
#   'incidents_recorded': 153,
#   'rate_per_100k_population': 2491.5},
#  {'year': 2021,
#   'lga': 'West Wimmera',
#   'incidents_recorded': 122,
#   'rate_per_100k_population': 3236.8},
#  {'year': 2021,
#   'lga': 'Queenscliffe',
#   'incidents_recorded': 82,
#   'rate_per_100k_population': 2727.9},
#  {'year': 2020,
#   'lga': 'Melbourne',
#   'incidents_recorded': 26881,
#   'rate_per_100k_population': 14628.6},
#  {'year': 2020,
#   'lga': 'Casey',
#   'incidents_recorded': 17157,
#   'rate_per_100k_population': 4705.7},
#  {'year': 2020,
#   'lga': 'Greater Geelong',
#   'incidents_recorded': 17002,
#   'rate_per_100k_population': 6419.1},
#  {'year': 2020,
#   'lga': 'Hume',
#   'incidents_recorded': 15894,
#   'rate_per_100k_population': 6589.9},
#  {'year': 2020,
#   'lga': 'Brimbank',
#   'incidents_recorded': 15483,
#   'rate_per_100k_population': 7434.9},
#  {'year': 2020,
#   'lga': 'Greater Dandenong',
#   'incidents_recorded': 14725,
#   'rate_per_100k_population': 8746.0},
#  {'year': 2020,
#   'lga': 'Wyndham',
#   'incidents_recorded': 13874,
#   'rate_per_100k_population': 4897.4},
#  {'year': 2020,
#   'lga': 'Whittlesea',
#   'incidents_recorded': 12246,
#   'rate_per_100k_population': 5177.2},
#  {'year': 2020,
#   'lga': 'Darebin',
#   'incidents_recorded': 11898,
#   'rate_per_100k_population': 7149.0},
#  {'year': 2020,
#   'lga': 'Yarra',
#   'incidents_recorded': 11433,
#   'rate_per_100k_population': 11086.5},
#  {'year': 2020,
#   'lga': 'Moreland',
#   'incidents_recorded': 11102,
#   'rate_per_100k_population': 5881.5},
#  {'year': 2020,
#   'lga': 'Frankston',
#   'incidents_recorded': 11100,
#   'rate_per_100k_population': 7743.9},
#  {'year': 2020,
#   'lga': 'Latrobe',
#   'incidents_recorded': 10076,
#   'rate_per_100k_population': 13272.7},
#  {'year': 2020,
#   'lga': 'Port Phillip',
#   'incidents_recorded': 9984,
#   'rate_per_100k_population': 8571.7},
#  {'year': 2020,
#   'lga': 'Monash',
#   'incidents_recorded': 9580,
#   'rate_per_100k_population': 4674.6},
#  {'year': 2020,
#   'lga': 'Stonnington',
#   'incidents_recorded': 9464,
#   'rate_per_100k_population': 7978.8},
#  {'year': 2020,
#   'lga': 'Melton',
#   'incidents_recorded': 9323,
#   'rate_per_100k_population': 5404.6},
#  {'year': 2020,
#   'lga': 'Kingston',
#   'incidents_recorded': 9036,
#   'rate_per_100k_population': 5401.3},
#  {'year': 2020,
#   'lga': 'Knox',
#   'incidents_recorded': 8877,
#   'rate_per_100k_population': 5375.2},
#  {'year': 2020,
#   'lga': 'Ballarat',
#   'incidents_recorded': 8713,
#   'rate_per_100k_population': 7824.1},
#  {'year': 2020,
#   'lga': 'Mornington Peninsula',
#   'incidents_recorded': 8620,
#   'rate_per_100k_population': 5104.8},
#  {'year': 2020,
#   'lga': 'Greater Bendigo',
#   'incidents_recorded': 8324,
#   'rate_per_100k_population': 6937.8},
#  {'year': 2020,
#   'lga': 'Whitehorse',
#   'incidents_recorded': 7355,
#   'rate_per_100k_population': 4069.5},
#  {'year': 2020,
#   'lga': 'Maribyrnong',
#   'incidents_recorded': 7308,
#   'rate_per_100k_population': 7694.1},
#  {'year': 2020,
#   'lga': 'Banyule',
#   'incidents_recorded': 7265,
#   'rate_per_100k_population': 5506.3},
#  {'year': 2020,
#   'lga': 'Moonee Valley',
#   'incidents_recorded': 6720,
#   'rate_per_100k_population': 5100.5},
#  {'year': 2020,
#   'lga': 'Boroondara',
#   'incidents_recorded': 6522,
#   'rate_per_100k_population': 3563.5},
#  {'year': 2020,
#   'lga': 'Greater Shepparton',
#   'incidents_recorded': 6384,
#   'rate_per_100k_population': 9518.4},
#  {'year': 2020,
#   'lga': 'Yarra Ranges',
#   'incidents_recorded': 6190,
#   'rate_per_100k_population': 3869.8},
#  {'year': 2020,
#   'lga': 'Glen Eira',
#   'incidents_recorded': 6105,
#   'rate_per_100k_population': 3858.6},
#  {'year': 2020,
#   'lga': 'Maroondah',
#   'incidents_recorded': 5921,
#   'rate_per_100k_population': 4958.9},
#  {'year': 2020,
#   'lga': 'Mildura',
#   'incidents_recorded': 5547,
#   'rate_per_100k_population': 9916.5},
#  {'year': 2020,
#   'lga': 'Cardinia',
#   'incidents_recorded': 5449,
#   'rate_per_100k_population': 4689.6},
#  {'year': 2020,
#   'lga': 'Hobsons Bay',
#   'incidents_recorded': 4905,
#   'rate_per_100k_population': 4995.5},
#  {'year': 2020,
#   'lga': 'Bayside',
#   'incidents_recorded': 4195,
#   'rate_per_100k_population': 3900.8},
#  {'year': 2020,
#   'lga': 'Manningham',
#   'incidents_recorded': 3742,
#   'rate_per_100k_population': 2902.4},
#  {'year': 2020,
#   'lga': 'East Gippsland',
#   'incidents_recorded': 3638,
#   'rate_per_100k_population': 7622.8},
#  {'year': 2020,
#   'lga': 'Baw Baw',
#   'incidents_recorded': 3587,
#   'rate_per_100k_population': 6535.6},
#  {'year': 2020,
#   'lga': 'Wellington',
#   'incidents_recorded': 3385,
#   'rate_per_100k_population': 7560.9},
#  {'year': 2020,
#   'lga': 'Mitchell',
#   'incidents_recorded': 3122,
#   'rate_per_100k_population': 6552.4},
#  {'year': 2020,
#   'lga': 'Wodonga',
#   'incidents_recorded': 2828,
#   'rate_per_100k_population': 6628.9},
#  {'year': 2020,
#   'lga': 'Campaspe',
#   'incidents_recorded': 2798,
#   'rate_per_100k_population': 7426.7},
#  {'year': 2020,
#   'lga': 'Warrnambool',
#   'incidents_recorded': 2468,
#   'rate_per_100k_population': 6945.7},
#  {'year': 2020,
#   'lga': 'Moira',
#   'incidents_recorded': 1835,
#   'rate_per_100k_population': 6113.0},
#  {'year': 2020,
#   'lga': 'Bass Coast',
#   'incidents_recorded': 1787,
#   'rate_per_100k_population': 4772.3},
#  {'year': 2020,
#   'lga': 'Swan Hill',
#   'incidents_recorded': 1770,
#   'rate_per_100k_population': 8619.9},
#  {'year': 2020,
#   'lga': 'Wangaratta',
#   'incidents_recorded': 1749,
#   'rate_per_100k_population': 5990.3},
#  {'year': 2020,
#   'lga': 'Macedon Ranges',
#   'incidents_recorded': 1724,
#   'rate_per_100k_population': 3382.3},
#  {'year': 2020,
#   'lga': 'Nillumbik',
#   'incidents_recorded': 1691,
#   'rate_per_100k_population': 2592.8},
#  {'year': 2020,
#   'lga': 'Moorabool',
#   'incidents_recorded': 1641,
#   'rate_per_100k_population': 4556.7},
#  {'year': 2020,
#   'lga': 'South Gippsland',
#   'incidents_recorded': 1360,
#   'rate_per_100k_population': 4496.2},
#  {'year': 2020,
#   'lga': 'Horsham',
#   'incidents_recorded': 1356,
#   'rate_per_100k_population': 6773.9},
#  {'year': 2020,
#   'lga': 'Colac-Otway',
#   'incidents_recorded': 1280,
#   'rate_per_100k_population': 5909.0},
#  {'year': 2020,
#   'lga': 'Glenelg',
#   'incidents_recorded': 1165,
#   'rate_per_100k_population': 5937.5},
#  {'year': 2020,
#   'lga': 'Surf Coast',
#   'incidents_recorded': 1043,
#   'rate_per_100k_population': 2999.6},
#  {'year': 2020,
#   'lga': 'Benalla',
#   'incidents_recorded': 935,
#   'rate_per_100k_population': 6613.9},
#  {'year': 2020,
#   'lga': 'Ararat',
#   'incidents_recorded': 894,
#   'rate_per_100k_population': 7471.8},
#  {'year': 2020,
#   'lga': 'Mount Alexander',
#   'incidents_recorded': 894,
#   'rate_per_100k_population': 4469.8},
#  {'year': 2020,
#   'lga': 'Southern Grampians',
#   'incidents_recorded': 887,
#   'rate_per_100k_population': 5497.7},
#  {'year': 2020,
#   'lga': 'Central Goldfields',
#   'incidents_recorded': 866,
#   'rate_per_100k_population': 6614.7},
#  {'year': 2020,
#   'lga': 'Hepburn',
#   'incidents_recorded': 738,
#   'rate_per_100k_population': 4567.7},
#  {'year': 2020,
#   'lga': 'Northern Grampians',
#   'incidents_recorded': 735,
#   'rate_per_100k_population': 6445.7},
#  {'year': 2020,
#   'lga': 'Gannawarra',
#   'incidents_recorded': 608,
#   'rate_per_100k_population': 5846.2},
#  {'year': 2020,
#   'lga': 'Murrindindi',
#   'incidents_recorded': 598,
#   'rate_per_100k_population': 4078.8},
#  {'year': 2020,
#   'lga': 'Corangamite',
#   'incidents_recorded': 549,
#   'rate_per_100k_population': 3446.5},
#  {'year': 2020,
#   'lga': 'Moyne',
#   'incidents_recorded': 506,
#   'rate_per_100k_population': 2971.8},
#  {'year': 2020,
#   'lga': 'Strathbogie',
#   'incidents_recorded': 475,
#   'rate_per_100k_population': 4321.3},
#  {'year': 2020,
#   'lga': 'Golden Plains',
#   'incidents_recorded': 472,
#   'rate_per_100k_population': 1946.5},
#  {'year': 2020,
#   'lga': 'Alpine',
#   'incidents_recorded': 438,
#   'rate_per_100k_population': 3376.2},
#  {'year': 2020,
#   'lga': 'Indigo',
#   'incidents_recorded': 430,
#   'rate_per_100k_population': 2546.6},
#  {'year': 2020,
#   'lga': 'Loddon',
#   'incidents_recorded': 366,
#   'rate_per_100k_population': 4897.6},
#  {'year': 2020,
#   'lga': 'Pyrenees',
#   'incidents_recorded': 350,
#   'rate_per_100k_population': 4632.7},
#  {'year': 2020,
#   'lga': 'Mansfield',
#   'incidents_recorded': 337,
#   'rate_per_100k_population': 3557.1},
#  {'year': 2020,
#   'lga': 'Yarriambiack',
#   'incidents_recorded': 319,
#   'rate_per_100k_population': 4842.1},
#  {'year': 2020,
#   'lga': 'Buloke',
#   'incidents_recorded': 254,
#   'rate_per_100k_population': 4163.3},
#  {'year': 2020,
#   'lga': 'Hindmarsh',
#   'incidents_recorded': 246,
#   'rate_per_100k_population': 4399.1},
#  {'year': 2020,
#   'lga': 'Towong',
#   'incidents_recorded': 155,
#   'rate_per_100k_population': 2540.2},
#  {'year': 2020,
#   'lga': 'West Wimmera',
#   'incidents_recorded': 142,
#   'rate_per_100k_population': 3727.0},
#  {'year': 2020,
#   'lga': 'Queenscliffe',
#   'incidents_recorded': 101,
#   'rate_per_100k_population': 3357.7},
#  {'year': 2019,
#   'lga': 'Melbourne',
#   'incidents_recorded': 26561,
#   'rate_per_100k_population': 14839.0},
#  {'year': 2019,
#   'lga': 'Casey',
#   'incidents_recorded': 16219,
#   'rate_per_100k_population': 4582.1},
#  {'year': 2019,
#   'lga': 'Greater Geelong',
#   'incidents_recorded': 15781,
#   'rate_per_100k_population': 6094.5},
#  {'year': 2019,
#   'lga': 'Hume',
#   'incidents_recorded': 15592,
#   'rate_per_100k_population': 6676.2},
#  {'year': 2019,
#   'lga': 'Brimbank',
#   'incidents_recorded': 14664,
#   'rate_per_100k_population': 6997.3},
#  {'year': 2019,
#   'lga': 'Greater Dandenong',
#   'incidents_recorded': 14198,
#   'rate_per_100k_population': 8438.1},
#  {'year': 2019,
#   'lga': 'Whittlesea',
#   'incidents_recorded': 11910,
#   'rate_per_100k_population': 5171.6},
#  {'year': 2019,
#   'lga': 'Wyndham',
#   'incidents_recorded': 11462,
#   'rate_per_100k_population': 4235.7},
#  {'year': 2019,
#   'lga': 'Moreland',
#   'incidents_recorded': 11408,
#   'rate_per_100k_population': 6139.6},
#  {'year': 2019,
#   'lga': 'Darebin',
#   'incidents_recorded': 11247,
#   'rate_per_100k_population': 6848.6},
#  {'year': 2019,
#   'lga': 'Yarra',
#   'incidents_recorded': 11182,
#   'rate_per_100k_population': 11015.0},
#  {'year': 2019,
#   'lga': 'Frankston',
#   'incidents_recorded': 11157,
#   'rate_per_100k_population': 7821.5},
#  {'year': 2019,
#   'lga': 'Latrobe',
#   'incidents_recorded': 9942,
#   'rate_per_100k_population': 13159.0},
#  {'year': 2019,
#   'lga': 'Port Phillip',
#   'incidents_recorded': 9680,
#   'rate_per_100k_population': 8372.3},
#  {'year': 2019,
#   'lga': 'Kingston',
#   'incidents_recorded': 8608,
#   'rate_per_100k_population': 5191.7},
#  {'year': 2019,
#   'lga': 'Melton',
#   'incidents_recorded': 8332,
#   'rate_per_100k_population': 5051.7},
#  {'year': 2019,
#   'lga': 'Stonnington',
#   'incidents_recorded': 8170,
#   'rate_per_100k_population': 6936.9},
#  {'year': 2019,
#   'lga': 'Mornington Peninsula',
#   'incidents_recorded': 8160,
#   'rate_per_100k_population': 4868.2},
#  {'year': 2019,
#   'lga': 'Ballarat',
#   'incidents_recorded': 8129,
#   'rate_per_100k_population': 7423.5},
#  {'year': 2019,
#   'lga': 'Knox',
#   'incidents_recorded': 8093,
#   'rate_per_100k_population': 4918.2},
#  {'year': 2019,
#   'lga': 'Greater Bendigo',
#   'incidents_recorded': 8093,
#   'rate_per_100k_population': 6853.2},
#  {'year': 2019,
#   'lga': 'Monash',
#   'incidents_recorded': 8032,
#   'rate_per_100k_population': 3958.7},
#  {'year': 2019,
#   'lga': 'Banyule',
#   'incidents_recorded': 7007,
#   'rate_per_100k_population': 5322.9},
#  {'year': 2019,
#   'lga': 'Maribyrnong',
#   'incidents_recorded': 6669,
#   'rate_per_100k_population': 7134.0},
#  {'year': 2019,
#   'lga': 'Moonee Valley',
#   'incidents_recorded': 6486,
#   'rate_per_100k_population': 4977.2},
#  {'year': 2019,
#   'lga': 'Whitehorse',
#   'incidents_recorded': 6362,
#   'rate_per_100k_population': 3558.6},
#  {'year': 2019,
#   'lga': 'Greater Shepparton',
#   'incidents_recorded': 6229,
#   'rate_per_100k_population': 9366.8},
#  {'year': 2019,
#   'lga': 'Maroondah',
#   'incidents_recorded': 6034,
#   'rate_per_100k_population': 5089.0},
#  {'year': 2019,
#   'lga': 'Yarra Ranges',
#   'incidents_recorded': 5768,
#   'rate_per_100k_population': 3616.9},
#  {'year': 2019,
#   'lga': 'Boroondara',
#   'incidents_recorded': 5570,
#   'rate_per_100k_population': 3040.4},
#  {'year': 2019,
#   'lga': 'Mildura',
#   'incidents_recorded': 5493,
#   'rate_per_100k_population': 9847.8},
#  {'year': 2019,
#   'lga': 'Glen Eira',
#   'incidents_recorded': 4892,
#   'rate_per_100k_population': 3125.2},
#  {'year': 2019,
#   'lga': 'Hobsons Bay',
#   'incidents_recorded': 4848,
#   'rate_per_100k_population': 4958.8},
#  {'year': 2019,
#   'lga': 'Cardinia',
#   'incidents_recorded': 4697,
#   'rate_per_100k_population': 4187.1},
#  {'year': 2019,
#   'lga': 'Bayside',
#   'incidents_recorded': 3606,
#   'rate_per_100k_population': 3374.6},
#  {'year': 2019,
#   'lga': 'Manningham',
#   'incidents_recorded': 3411,
#   'rate_per_100k_population': 2673.5},
#  {'year': 2019,
#   'lga': 'East Gippsland',
#   'incidents_recorded': 3193,
#   'rate_per_100k_population': 6749.4},
#  {'year': 2019,
#   'lga': 'Baw Baw',
#   'incidents_recorded': 3179,
#   'rate_per_100k_population': 5953.9},
#  {'year': 2019,
#   'lga': 'Mitchell',
#   'incidents_recorded': 3034,
#   'rate_per_100k_population': 6583.2},
#  {'year': 2019,
#   'lga': 'Warrnambool',
#   'incidents_recorded': 3007,
#   'rate_per_100k_population': 8547.2},
#  {'year': 2019,
#   'lga': 'Wellington',
#   'incidents_recorded': 2921,
#   'rate_per_100k_population': 6582.1},
#  {'year': 2019,
#   'lga': 'Campaspe',
#   'incidents_recorded': 2919,
#   'rate_per_100k_population': 7760.2},
#  {'year': 2019,
#   'lga': 'Wodonga',
#   'incidents_recorded': 2421,
#   'rate_per_100k_population': 5752.9},
#  {'year': 2019,
#   'lga': 'Swan Hill',
#   'incidents_recorded': 1868,
#   'rate_per_100k_population': 9046.0},
#  {'year': 2019,
#   'lga': 'Bass Coast',
#   'incidents_recorded': 1782,
#   'rate_per_100k_population': 4907.1},
#  {'year': 2019,
#   'lga': 'Macedon Ranges',
#   'incidents_recorded': 1782,
#   'rate_per_100k_population': 3547.7},
#  {'year': 2019,
#   'lga': 'Moira',
#   'incidents_recorded': 1682,
#   'rate_per_100k_population': 5621.7},
#  {'year': 2019,
#   'lga': 'Wangaratta',
#   'incidents_recorded': 1639,
#   'rate_per_100k_population': 5616.1},
#  {'year': 2019,
#   'lga': 'Moorabool',
#   'incidents_recorded': 1633,
#   'rate_per_100k_population': 4658.9},
#  {'year': 2019,
#   'lga': 'Nillumbik',
#   'incidents_recorded': 1624,
#   'rate_per_100k_population': 2494.7},
#  {'year': 2019,
#   'lga': 'Horsham',
#   'incidents_recorded': 1436,
#   'rate_per_100k_population': 7208.8},
#  {'year': 2019,
#   'lga': 'Colac-Otway',
#   'incidents_recorded': 1321,
#   'rate_per_100k_population': 6126.5},
#  {'year': 2019,
#   'lga': 'Southern Grampians',
#   'incidents_recorded': 1108,
#   'rate_per_100k_population': 6882.8},
#  {'year': 2019,
#   'lga': 'South Gippsland',
#   'incidents_recorded': 996,
#   'rate_per_100k_population': 3330.0},
#  {'year': 2019,
#   'lga': 'Glenelg',
#   'incidents_recorded': 956,
#   'rate_per_100k_population': 4859.9},
#  {'year': 2019,
#   'lga': 'Central Goldfields',
#   'incidents_recorded': 917,
#   'rate_per_100k_population': 6956.5},
#  {'year': 2019,
#   'lga': 'Ararat',
#   'incidents_recorded': 912,
#   'rate_per_100k_population': 7700.1},
#  {'year': 2019,
#   'lga': 'Surf Coast',
#   'incidents_recorded': 899,
#   'rate_per_100k_population': 2687.0},
#  {'year': 2019,
#   'lga': 'Benalla',
#   'incidents_recorded': 877,
#   'rate_per_100k_population': 6249.1},
#  {'year': 2019,
#   'lga': 'Northern Grampians',
#   'incidents_recorded': 762,
#   'rate_per_100k_population': 6683.6},
#  {'year': 2019,
#   'lga': 'Mount Alexander',
#   'incidents_recorded': 751,
#   'rate_per_100k_population': 3802.3},
#  {'year': 2019,
#   'lga': 'Hepburn',
#   'incidents_recorded': 619,
#   'rate_per_100k_population': 3875.3},
#  {'year': 2019,
#   'lga': 'Murrindindi',
#   'incidents_recorded': 593,
#   'rate_per_100k_population': 4070.6},
#  {'year': 2019,
#   'lga': 'Gannawarra',
#   'incidents_recorded': 581,
#   'rate_per_100k_population': 5549.7},
#  {'year': 2019,
#   'lga': 'Golden Plains',
#   'incidents_recorded': 510,
#   'rate_per_100k_population': 2149.9},
#  {'year': 2019,
#   'lga': 'Corangamite',
#   'incidents_recorded': 487,
#   'rate_per_100k_population': 3040.5},
#  {'year': 2019,
#   'lga': 'Moyne',
#   'incidents_recorded': 459,
#   'rate_per_100k_population': 2707.6},
#  {'year': 2019,
#   'lga': 'Strathbogie',
#   'incidents_recorded': 448,
#   'rate_per_100k_population': 4156.6},
#  {'year': 2019,
#   'lga': 'Pyrenees',
#   'incidents_recorded': 419,
#   'rate_per_100k_population': 5609.1},
#  {'year': 2019,
#   'lga': 'Alpine',
#   'incidents_recorded': 399,
#   'rate_per_100k_population': 3114.3},
#  {'year': 2019,
#   'lga': 'Loddon',
#   'incidents_recorded': 386,
#   'rate_per_100k_population': 5145.3},
#  {'year': 2019,
#   'lga': 'Indigo',
#   'incidents_recorded': 371,
#   'rate_per_100k_population': 2221.7},
#  {'year': 2019,
#   'lga': 'Mansfield',
#   'incidents_recorded': 321,
#   'rate_per_100k_population': 3498.6},
#  {'year': 2019,
#   'lga': 'Yarriambiack',
#   'incidents_recorded': 320,
#   'rate_per_100k_population': 4821.5},
#  {'year': 2019,
#   'lga': 'Hindmarsh',
#   'incidents_recorded': 250,
#   'rate_per_100k_population': 4475.5},
#  {'year': 2019,
#   'lga': 'Buloke',
#   'incidents_recorded': 214,
#   'rate_per_100k_population': 3495.0},
#  {'year': 2019,
#   'lga': 'Towong',
#   'incidents_recorded': 173,
#   'rate_per_100k_population': 2864.7},
#  {'year': 2019,
#   'lga': 'West Wimmera',
#   'incidents_recorded': 125,
#   'rate_per_100k_population': 3256.1},
#  {'year': 2019,
#   'lga': 'Queenscliffe',
#   'incidents_recorded': 118,
#   'rate_per_100k_population': 4015.0},
#  {'year': 2018,
#   'lga': 'Melbourne',
#   'incidents_recorded': 26830,
#   'rate_per_100k_population': 15753.0},
#  {'year': 2018,
#   'lga': 'Greater Geelong',
#   'incidents_recorded': 16864,
#   'rate_per_100k_population': 6686.0},
#  {'year': 2018,
#   'lga': 'Hume',
#   'incidents_recorded': 15266,
#   'rate_per_100k_population': 6802.3},
#  {'year': 2018,
#   'lga': 'Casey',
#   'incidents_recorded': 14726,
#   'rate_per_100k_population': 4325.5},
#  {'year': 2018,
#   'lga': 'Greater Dandenong',
#   'incidents_recorded': 13628,
#   'rate_per_100k_population': 8202.7},
#  {'year': 2018,
#   'lga': 'Brimbank',
#   'incidents_recorded': 13551,
#   'rate_per_100k_population': 6491.7},
#  {'year': 2018,
#   'lga': 'Darebin',
#   'incidents_recorded': 11425,
#   'rate_per_100k_population': 7067.6},
#  {'year': 2018,
#   'lga': 'Whittlesea',
#   'incidents_recorded': 11340,
#   'rate_per_100k_population': 5077.3},
#  {'year': 2018,
#   'lga': 'Moreland',
#   'incidents_recorded': 11021,
#   'rate_per_100k_population': 6062.8},
#  {'year': 2018,
#   'lga': 'Wyndham',
#   'incidents_recorded': 10861,
#   'rate_per_100k_population': 4253.1},
#  {'year': 2018,
#   'lga': 'Frankston',
#   'incidents_recorded': 10721,
#   'rate_per_100k_population': 7558.1},
#  {'year': 2018,
#   'lga': 'Yarra',
#   'incidents_recorded': 10647,
#   'rate_per_100k_population': 10801.8},
#  {'year': 2018,
#   'lga': 'Port Phillip',
#   'incidents_recorded': 9799,
#   'rate_per_100k_population': 8651.4},
#  {'year': 2018,
#   'lga': 'Latrobe',
#   'incidents_recorded': 9376,
#   'rate_per_100k_population': 12466.6},
#  {'year': 2018,
#   'lga': 'Ballarat',
#   'incidents_recorded': 8900,
#   'rate_per_100k_population': 8292.6},
#  {'year': 2018,
#   'lga': 'Mornington Peninsula',
#   'incidents_recorded': 8519,
#   'rate_per_100k_population': 5137.4},
#  {'year': 2018,
#   'lga': 'Knox',
#   'incidents_recorded': 8518,
#   'rate_per_100k_population': 5219.0},
#  {'year': 2018,
#   'lga': 'Monash',
#   'incidents_recorded': 8299,
#   'rate_per_100k_population': 4145.1},
#  {'year': 2018,
#   'lga': 'Stonnington',
#   'incidents_recorded': 8005,
#   'rate_per_100k_population': 6884.2},
#  {'year': 2018,
#   'lga': 'Kingston',
#   'incidents_recorded': 7907,
#   'rate_per_100k_population': 4837.5},
#  {'year': 2018,
#   'lga': 'Melton',
#   'incidents_recorded': 7808,
#   'rate_per_100k_population': 4982.2},
#  {'year': 2018,
#   'lga': 'Banyule',
#   'incidents_recorded': 7369,
#   'rate_per_100k_population': 5657.6},
#  {'year': 2018,
#   'lga': 'Greater Bendigo',
#   'incidents_recorded': 7089,
#   'rate_per_100k_population': 6109.0},
#  {'year': 2018,
#   'lga': 'Moonee Valley',
#   'incidents_recorded': 6692,
#   'rate_per_100k_population': 5232.0},
#  {'year': 2018,
#   'lga': 'Maribyrnong',
#   'incidents_recorded': 6585,
#   'rate_per_100k_population': 7203.6},
#  {'year': 2018,
#   'lga': 'Whitehorse',
#   'incidents_recorded': 6497,
#   'rate_per_100k_population': 3685.8},
#  {'year': 2018,
#   'lga': 'Greater Shepparton',
#   'incidents_recorded': 5980,
#   'rate_per_100k_population': 9059.5},
#  {'year': 2018,
#   'lga': 'Maroondah',
#   'incidents_recorded': 5880,
#   'rate_per_100k_population': 5004.0},
#  {'year': 2018,
#   'lga': 'Boroondara',
#   'incidents_recorded': 5632,
#   'rate_per_100k_population': 3105.2},
#  {'year': 2018,
#   'lga': 'Yarra Ranges',
#   'incidents_recorded': 5516,
#   'rate_per_100k_population': 3487.4},
#  {'year': 2018,
#   'lga': 'Glen Eira',
#   'incidents_recorded': 5233,
#   'rate_per_100k_population': 3399.8},
#  {'year': 2018,
#   'lga': 'Hobsons Bay',
#   'incidents_recorded': 4830,
#   'rate_per_100k_population': 5006.2},
#  {'year': 2018,
#   'lga': 'Mildura',
#   'incidents_recorded': 4822,
#   'rate_per_100k_population': 8685.8},
#  {'year': 2018,
#   'lga': 'Cardinia',
#   'incidents_recorded': 4294,
#   'rate_per_100k_population': 4008.7},
#  {'year': 2018,
#   'lga': 'Bayside',
#   'incidents_recorded': 3898,
#   'rate_per_100k_population': 3686.2},
#  {'year': 2018,
#   'lga': 'Manningham',
#   'incidents_recorded': 3660,
#   'rate_per_100k_population': 2915.5},
#  {'year': 2018,
#   'lga': 'East Gippsland',
#   'incidents_recorded': 3056,
#   'rate_per_100k_population': 6527.7},
#  {'year': 2018,
#   'lga': 'Mitchell',
#   'incidents_recorded': 3041,
#   'rate_per_100k_population': 6864.9},
#  {'year': 2018,
#   'lga': 'Baw Baw',
#   'incidents_recorded': 2929,
#   'rate_per_100k_population': 5631.4},
#  {'year': 2018,
#   'lga': 'Warrnambool',
#   'incidents_recorded': 2707,
#   'rate_per_100k_population': 7764.7},
#  {'year': 2018,
#   'lga': 'Wellington',
#   'incidents_recorded': 2657,
#   'rate_per_100k_population': 6036.3},
#  {'year': 2018,
#   'lga': 'Campaspe',
#   'incidents_recorded': 2511,
#   'rate_per_100k_population': 6680.0},
#  {'year': 2018,
#   'lga': 'Wodonga',
#   'incidents_recorded': 2369,
#   'rate_per_100k_population': 5718.2},
#  {'year': 2018,
#   'lga': 'Moorabool',
#   'incidents_recorded': 1823,
#   'rate_per_100k_population': 5337.3},
#  {'year': 2018,
#   'lga': 'Bass Coast',
#   'incidents_recorded': 1799,
#   'rate_per_100k_population': 5092.6},
#  {'year': 2018,
#   'lga': 'Wangaratta',
#   'incidents_recorded': 1799,
#   'rate_per_100k_population': 6185.1},
#  {'year': 2018,
#   'lga': 'Nillumbik',
#   'incidents_recorded': 1795,
#   'rate_per_100k_population': 2764.0},
#  {'year': 2018,
#   'lga': 'Swan Hill',
#   'incidents_recorded': 1752,
#   'rate_per_100k_population': 8439.3},
#  {'year': 2018,
#   'lga': 'Horsham',
#   'incidents_recorded': 1637,
#   'rate_per_100k_population': 8236.9},
#  {'year': 2018,
#   'lga': 'Macedon Ranges',
#   'incidents_recorded': 1523,
#   'rate_per_100k_population': 3083.8},
#  {'year': 2018,
#   'lga': 'Moira',
#   'incidents_recorded': 1504,
#   'rate_per_100k_population': 5047.5},
#  {'year': 2018,
#   'lga': 'Colac-Otway',
#   'incidents_recorded': 1242,
#   'rate_per_100k_population': 5776.2},
#  {'year': 2018,
#   'lga': 'Glenelg',
#   'incidents_recorded': 1196,
#   'rate_per_100k_population': 6082.2},
#  {'year': 2018,
#   'lga': 'South Gippsland',
#   'incidents_recorded': 1006,
#   'rate_per_100k_population': 3401.5},
#  {'year': 2018,
#   'lga': 'Southern Grampians',
#   'incidents_recorded': 1004,
#   'rate_per_100k_population': 6222.9},
#  {'year': 2018,
#   'lga': 'Benalla',
#   'incidents_recorded': 980,
#   'rate_per_100k_population': 6988.5},
#  {'year': 2018,
#   'lga': 'Surf Coast',
#   'incidents_recorded': 952,
#   'rate_per_100k_population': 2951.8},
#  {'year': 2018,
#   'lga': 'Central Goldfields',
#   'incidents_recorded': 907,
#   'rate_per_100k_population': 6867.1},
#  {'year': 2018,
#   'lga': 'Ararat',
#   'incidents_recorded': 884,
#   'rate_per_100k_population': 7494.7},
#  {'year': 2018,
#   'lga': 'Northern Grampians',
#   'incidents_recorded': 802,
#   'rate_per_100k_population': 7016.6},
#  {'year': 2018,
#   'lga': 'Mount Alexander',
#   'incidents_recorded': 733,
#   'rate_per_100k_population': 3756.3},
#  {'year': 2018,
#   'lga': 'Hepburn',
#   'incidents_recorded': 639,
#   'rate_per_100k_population': 4041.2},
#  {'year': 2018,
#   'lga': 'Corangamite',
#   'incidents_recorded': 620,
#   'rate_per_100k_population': 3841.6},
#  {'year': 2018,
#   'lga': 'Murrindindi',
#   'incidents_recorded': 532,
#   'rate_per_100k_population': 3674.5},
#  {'year': 2018,
#   'lga': 'Golden Plains',
#   'incidents_recorded': 481,
#   'rate_per_100k_population': 2080.6},
#  {'year': 2018,
#   'lga': 'Moyne',
#   'incidents_recorded': 464,
#   'rate_per_100k_population': 2747.7},
#  {'year': 2018,
#   'lga': 'Mansfield',
#   'incidents_recorded': 453,
#   'rate_per_100k_population': 5045.1},
#  {'year': 2018,
#   'lga': 'Strathbogie',
#   'incidents_recorded': 438,
#   'rate_per_100k_population': 4115.0},
#  {'year': 2018,
#   'lga': 'Gannawarra',
#   'incidents_recorded': 417,
#   'rate_per_100k_population': 3954.1},
#  {'year': 2018,
#   'lga': 'Yarriambiack',
#   'incidents_recorded': 358,
#   'rate_per_100k_population': 5377.0},
#  {'year': 2018,
#   'lga': 'Indigo',
#   'incidents_recorded': 339,
#   'rate_per_100k_population': 2055.9},
#  {'year': 2018,
#   'lga': 'Alpine',
#   'incidents_recorded': 319,
#   'rate_per_100k_population': 2505.9},
#  {'year': 2018,
#   'lga': 'Loddon',
#   'incidents_recorded': 317,
#   'rate_per_100k_population': 4219.4},
#  {'year': 2018,
#   'lga': 'Pyrenees',
#   'incidents_recorded': 307,
#   'rate_per_100k_population': 4175.2},
#  {'year': 2018,
#   'lga': 'Hindmarsh',
#   'incidents_recorded': 253,
#   'rate_per_100k_population': 4482.6},
#  {'year': 2018,
#   'lga': 'Towong',
#   'incidents_recorded': 171,
#   'rate_per_100k_population': 2824.6},
#  {'year': 2018,
#   'lga': 'Buloke',
#   'incidents_recorded': 168,
#   'rate_per_100k_population': 2717.1},
#  {'year': 2018,
#   'lga': 'West Wimmera',
#   'incidents_recorded': 114,
#   'rate_per_100k_population': 2951.8},
#  {'year': 2018,
#   'lga': 'Queenscliffe',
#   'incidents_recorded': 108,
#   'rate_per_100k_population': 3621.7},
#  {'year': 2017,
#   'lga': 'Melbourne',
#   'incidents_recorded': 28093,
#   'rate_per_100k_population': 17652.9},
#  {'year': 2017,
#   'lga': 'Casey',
#   'incidents_recorded': 18111,
#   'rate_per_100k_population': 5542.4},
#  {'year': 2017,
#   'lga': 'Greater Geelong',
#   'incidents_recorded': 18085,
#   'rate_per_100k_population': 7359.8},
#  {'year': 2017,
#   'lga': 'Hume',
#   'incidents_recorded': 17033,
#   'rate_per_100k_population': 7913.6},
#  {'year': 2017,
#   'lga': 'Greater Dandenong',
#   'incidents_recorded': 15455,
#   'rate_per_100k_population': 9451.6},
#  {'year': 2017,
#   'lga': 'Brimbank',
#   'incidents_recorded': 14674,
#   'rate_per_100k_population': 7089.0},
#  {'year': 2017,
#   'lga': 'Darebin',
#   'incidents_recorded': 13201,
#   'rate_per_100k_population': 8315.5},
#  {'year': 2017,
#   'lga': 'Whittlesea',
#   'incidents_recorded': 12870,
#   'rate_per_100k_population': 5967.0},
#  {'year': 2017,
#   'lga': 'Frankston',
#   'incidents_recorded': 12353,
#   'rate_per_100k_population': 8778.6},
#  {'year': 2017,
#   'lga': 'Wyndham',
#   'incidents_recorded': 11966,
#   'rate_per_100k_population': 4963.7},
#  {'year': 2017,
#   'lga': 'Moreland',
#   'incidents_recorded': 11801,
#   'rate_per_100k_population': 6668.2},
#  {'year': 2017,
#   'lga': 'Yarra',
#   'incidents_recorded': 11310,
#   'rate_per_100k_population': 11782.0},
#  {'year': 2017,
#   'lga': 'Port Phillip',
#   'incidents_recorded': 10493,
#   'rate_per_100k_population': 9482.5},
#  {'year': 2017,
#   'lga': 'Latrobe',
#   'incidents_recorded': 10348,
#   'rate_per_100k_population': 13814.3},
#  {'year': 2017,
#   'lga': 'Knox',
#   'incidents_recorded': 9324,
#   'rate_per_100k_population': 5761.7},
#  {'year': 2017,
#   'lga': 'Ballarat',
#   'incidents_recorded': 9218,
#   'rate_per_100k_population': 8743.9},
#  {'year': 2017,
#   'lga': 'Stonnington',
#   'incidents_recorded': 9108,
#   'rate_per_100k_population': 8005.5},
#  {'year': 2017,
#   'lga': 'Monash',
#   'incidents_recorded': 9028,
#   'rate_per_100k_population': 4584.6},
#  {'year': 2017,
#   'lga': 'Melton',
#   'incidents_recorded': 8968,
#   'rate_per_100k_population': 6034.3},
#  {'year': 2017,
#   'lga': 'Mornington Peninsula',
#   'incidents_recorded': 8942,
#   'rate_per_100k_population': 5458.0},
#  {'year': 2017,
#   'lga': 'Kingston',
#   'incidents_recorded': 8381,
#   'rate_per_100k_population': 5203.9},
#  {'year': 2017,
#   'lga': 'Greater Bendigo',
#   'incidents_recorded': 8032,
#   'rate_per_100k_population': 7040.0},
#  {'year': 2017,
#   'lga': 'Moonee Valley',
#   'incidents_recorded': 7759,
#   'rate_per_100k_population': 6186.9},
#  {'year': 2017,
#   'lga': 'Banyule',
#   'incidents_recorded': 7447,
#   'rate_per_100k_population': 5767.7},
#  {'year': 2017,
#   'lga': 'Maribyrnong',
#   'incidents_recorded': 7193,
#   'rate_per_100k_population': 8049.3},
#  {'year': 2017,
#   'lga': 'Maroondah',
#   'incidents_recorded': 7070,
#   'rate_per_100k_population': 6078.0},
#  {'year': 2017,
#   'lga': 'Boroondara',
#   'incidents_recorded': 7007,
#   'rate_per_100k_population': 3899.8},
#  {'year': 2017,
#   'lga': 'Whitehorse',
#   'incidents_recorded': 6614,
#   'rate_per_100k_population': 3817.3},
#  {'year': 2017,
#   'lga': 'Yarra Ranges',
#   'incidents_recorded': 6435,
#   'rate_per_100k_population': 4102.1},
#  {'year': 2017,
#   'lga': 'Greater Shepparton',
#   'incidents_recorded': 6307,
#   'rate_per_100k_population': 9621.1},
#  {'year': 2017,
#   'lga': 'Glen Eira',
#   'incidents_recorded': 5873,
#   'rate_per_100k_population': 3877.7},
#  {'year': 2017,
#   'lga': 'Hobsons Bay',
#   'incidents_recorded': 5229,
#   'rate_per_100k_population': 5500.1},
#  {'year': 2017,
#   'lga': 'Mildura',
#   'incidents_recorded': 5216,
#   'rate_per_100k_population': 9459.2},
#  {'year': 2017,
#   'lga': 'Cardinia',
#   'incidents_recorded': 5199,
#   'rate_per_100k_population': 5077.0},
#  {'year': 2017,
#   'lga': 'Bayside',
#   'incidents_recorded': 4127,
#   'rate_per_100k_population': 3957.5},
#  {'year': 2017,
#   'lga': 'Manningham',
#   'incidents_recorded': 4064,
#   'rate_per_100k_population': 3270.3},
#  {'year': 2017,
#   'lga': 'Wellington',
#   'incidents_recorded': 3224,
#   'rate_per_100k_population': 7360.6},
#  {'year': 2017,
#   'lga': 'Mitchell',
#   'incidents_recorded': 3141,
#   'rate_per_100k_population': 7321.2},
#  {'year': 2017,
#   'lga': 'East Gippsland',
#   'incidents_recorded': 2952,
#   'rate_per_100k_population': 6398.5},
#  {'year': 2017,
#   'lga': 'Baw Baw',
#   'incidents_recorded': 2894,
#   'rate_per_100k_population': 5710.8},
#  {'year': 2017,
#   'lga': 'Campaspe',
#   'incidents_recorded': 2741,
#   'rate_per_100k_population': 7290.5},
#  {'year': 2017,
#   'lga': 'Warrnambool',
#   'incidents_recorded': 2589,
#   'rate_per_100k_population': 7489.4},
#  {'year': 2017,
#   'lga': 'Wodonga',
#   'incidents_recorded': 2532,
#   'rate_per_100k_population': 6204.1},
#  {'year': 2017,
#   'lga': 'Nillumbik',
#   'incidents_recorded': 2171,
#   'rate_per_100k_population': 3359.7},
#  {'year': 2017,
#   'lga': 'Bass Coast',
#   'incidents_recorded': 1986,
#   'rate_per_100k_population': 5775.6},
#  {'year': 2017,
#   'lga': 'Moorabool',
#   'incidents_recorded': 1981,
#   'rate_per_100k_population': 5923.7},
#  {'year': 2017,
#   'lga': 'Wangaratta',
#   'incidents_recorded': 1877,
#   'rate_per_100k_population': 6505.4},
#  {'year': 2017,
#   'lga': 'Horsham',
#   'incidents_recorded': 1756,
#   'rate_per_100k_population': 8830.8},
#  {'year': 2017,
#   'lga': 'Swan Hill',
#   'incidents_recorded': 1753,
#   'rate_per_100k_population': 8408.9},
#  {'year': 2017,
#   'lga': 'Macedon Ranges',
#   'incidents_recorded': 1644,
#   'rate_per_100k_population': 3395.2},
#  {'year': 2017,
#   'lga': 'Colac-Otway',
#   'incidents_recorded': 1616,
#   'rate_per_100k_population': 7540.8},
#  {'year': 2017,
#   'lga': 'Glenelg',
#   'incidents_recorded': 1380,
#   'rate_per_100k_population': 7007.9},
#  {'year': 2017,
#   'lga': 'Moira',
#   'incidents_recorded': 1377,
#   'rate_per_100k_population': 4643.9},
#  {'year': 2017,
#   'lga': 'South Gippsland',
#   'incidents_recorded': 1145,
#   'rate_per_100k_population': 3905.1},
#  {'year': 2017,
#   'lga': 'Surf Coast',
#   'incidents_recorded': 1068,
#   'rate_per_100k_population': 3407.0},
#  {'year': 2017,
#   'lga': 'Southern Grampians',
#   'incidents_recorded': 1025,
#   'rate_per_100k_population': 6357.4},
#  {'year': 2017,
#   'lga': 'Benalla',
#   'incidents_recorded': 1000,
#   'rate_per_100k_population': 7156.1},
#  {'year': 2017,
#   'lga': 'Central Goldfields',
#   'incidents_recorded': 950,
#   'rate_per_100k_population': 7225.4},
#  {'year': 2017,
#   'lga': 'Northern Grampians',
#   'incidents_recorded': 933,
#   'rate_per_100k_population': 8101.1},
#  {'year': 2017,
#   'lga': 'Ararat',
#   'incidents_recorded': 909,
#   'rate_per_100k_population': 7732.2},
#  {'year': 2017,
#   'lga': 'Mount Alexander',
#   'incidents_recorded': 908,
#   'rate_per_100k_population': 4705.4},
#  {'year': 2017,
#   'lga': 'Corangamite',
#   'incidents_recorded': 801,
#   'rate_per_100k_population': 4941.4},
#  {'year': 2017,
#   'lga': 'Hepburn',
#   'incidents_recorded': 723,
#   'rate_per_100k_population': 4626.0},
#  {'year': 2017,
#   'lga': 'Golden Plains',
#   'incidents_recorded': 590,
#   'rate_per_100k_population': 2614.3},
#  {'year': 2017,
#   'lga': 'Gannawarra',
#   'incidents_recorded': 528,
#   'rate_per_100k_population': 4995.7},
#  {'year': 2017,
#   'lga': 'Murrindindi',
#   'incidents_recorded': 524,
#   'rate_per_100k_population': 3681.3},
#  {'year': 2017,
#   'lga': 'Moyne',
#   'incidents_recorded': 488,
#   'rate_per_100k_population': 2906.0},
#  {'year': 2017,
#   'lga': 'Mansfield',
#   'incidents_recorded': 470,
#   'rate_per_100k_population': 5343.3},
#  {'year': 2017,
#   'lga': 'Strathbogie',
#   'incidents_recorded': 462,
#   'rate_per_100k_population': 4406.7},
#  {'year': 2017,
#   'lga': 'Loddon',
#   'incidents_recorded': 393,
#   'rate_per_100k_population': 5235.1},
#  {'year': 2017,
#   'lga': 'Pyrenees',
#   'incidents_recorded': 360,
#   'rate_per_100k_population': 4892.6},
#  {'year': 2017,
#   'lga': 'Indigo',
#   'incidents_recorded': 350,
#   'rate_per_100k_population': 2142.9},
#  {'year': 2017,
#   'lga': 'Yarriambiack',
#   'incidents_recorded': 330,
#   'rate_per_100k_population': 4937.2},
#  {'year': 2017,
#   'lga': 'Hindmarsh',
#   'incidents_recorded': 288,
#   'rate_per_100k_population': 5036.7},
#  {'year': 2017,
#   'lga': 'Alpine',
#   'incidents_recorded': 280,
#   'rate_per_100k_population': 2215.5},
#  {'year': 2017,
#   'lga': 'Towong',
#   'incidents_recorded': 174,
#   'rate_per_100k_population': 2881.3},
#  {'year': 2017,
#   'lga': 'Buloke',
#   'incidents_recorded': 141,
#   'rate_per_100k_population': 2272.4},
#  {'year': 2017,
#   'lga': 'Queenscliffe',
#   'incidents_recorded': 135,
#   'rate_per_100k_population': 4562.4},
#  {'year': 2017,
#   'lga': 'West Wimmera',
#   'incidents_recorded': 123,
#   'rate_per_100k_population': 3158.7}]

# %%
collection_crime.insert_many(crime_incidents_dict)

# %%
grouped_victim_dict = grouped_offence_df_final.to_dict("records")

# %%
collection_victim.insert_many(grouped_victim_dict)

# %%
grouped_offence_dict = grouped_victim_df_final.to_dict("records")

# %%
collection_offence.insert_many(grouped_offence_dict)
